# %%
import pandas
import os
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
plt.style.use('ggplot')

# %%
# %matplotlib inline

# %%
def convert_to_us(df):
    # Convert ns component of sending time to seconds, then combine with 
    # second component
    df['time_ns'] = df['time_ns'].apply(lambda x: float(x) / 1e9)

    df['time(s)'] = df['time_ns'] + df['time_s']

    # Convert RTT nanosecond component to seconds, add seconds component, 
    # then convert to us
    df['rtt(us)'] = (df['rtt_ns'].apply(lambda x: float(x) / 1e9) + 
                     df['rtt_s']) * 1e6
    
    return df

# %%
def remove_outliers(df):
    # Remove the outliers
    return df[np.abs(df["rtt(ms)"]-df["rtt(ms)"].mean())<=(3*df["rtt(ms)"]
                                                           .std())]

# %%
def isolate_spikes(df, thresh):
    # isolate spikes in data based on thresh
    spikes = df.loc[df['rtt(us)'] > thresh]
    spikes["diff_time(s)"] = spikes["time(s)"].diff()
    spikes.plot(x="time(s)", y="diff_time(s)")
    
    return spikes

# %%
def persec_median(df):
    # Groups data by seconds and returns the median for each second bin
    return df.groupby(['time_s']).median()

# %%
os.chdir("/home/theano/emulab/sequencer/tsch/drat/client")
df = pandas.read_csv('out3', sep=",", names=["time_s", "time_ns", "rtt_s", "rtt_ns"])

# %%
med.plot(x="time(s)", y="rtt(us)", kind="line")

# %%
df_nooutliers[:10000].plot(x="time(s)", y="rtt(ms)")

# %%
# Plot unmodified RTTs
df[:1000000].plot(x="time(s)", y="rtt(us)")

# %%
spikes_local = df.loc[df['rtt(us)'] > 400]
spikes_local["diff_time(s)"] = spikes_local["time(s)"].diff()
spikes_local.plot(x="time(s)", y="diff_time(s)")
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
spikes = df.loc[df['rtt(ms)'] > 0.6]

# %%
spikes.plot(x="time(s)", y="diff_time(s)")

# %%
# local, with byte counting
os.chdir("/home/theano/emulab/sequencer/tsch/drat/client")
df4 = pandas.read_csv('out4', sep=",", names=["time_s", "time_ns", "rtt_s", "rtt_ns"])

df4 = convert_to_us(df4)

df4.plot(x="time(s)", y="rtt(us)")

# %%
# local, with byte counting, round 2
os.chdir("/home/theano/emulab/sequencer/tsch/drat/client")
df5 = pandas.read_csv('out5', sep=",", names=["time_s", "time_ns", "rtt_s", "rtt_ns"])

df5 = convert_to_us(df5)

df5.plot(x="time(s)", y="rtt(us)")

# %%
# local with 100us sleep before taking end time
df6 = pandas.read_csv('out6', sep=",", names=["time_s", "time_ns", "rtt_s", "rtt_ns"])

df6 = convert_to_us(df6)

df6.plot(x="time(s)", y="rtt(us)")

# %%
# local, 1000us sleep
df7 = pandas.read_csv('out7', sep=",", names=["time_s", "time_ns", "rtt_s", "rtt_ns"])

df7 = convert_to_us(df7)

df7.plot(x="time(s)", y="rtt(us)")

# %%
df7_spikes = isolate_spikes(df7, 1250)
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
