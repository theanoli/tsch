# %%
# To find values within a column...
#df.loc[df['column_name'] == some_value]
#x = dfs[0][1]
#x.loc[x["ncli"] == 8151]

# %%
import os
import re
import math
import pandas as pd
import numpy as np

import plotly
import plotly.plotly as py
from plotly.graph_objs import *

plotly.tools.set_credentials_file(username='theano', api_key='hkYRYxjyM0aAGA5nmGq1')

# %%
import matplotlib.pyplot as plt

import matplotlib
matplotlib.style.use('ggplot')

# %%
home = os.getcwd()
print(home)
sorted([x for x in os.listdir(home)])
collectl_stats = ['Date', '[CPU]User%', '[CPU]Nice%', '[CPU]Sys%', '[CPU]Wait%',
                               '[CPU]Irq%', '[CPU]Soft%', '[CPU]Steal%', '[CPU]Idle%',
                               '[CPU]Totl%', '[CPU]Intrpt/sec', '[CPU]Ctx/sec', '[CPU]Proc/sec',
                               '[CPU]ProcQue', '[CPU]ProcRun', '[CPU]L-Avg1', '[CPU]L-Avg5',
                               '[CPU]L-Avg15', '[CPU]RunTot', '[CPU]BlkTot']
loaded_files = []
# Out:
# /home/theano/mountpoint/tsch/mininetpipe/results/2017-12-14-08-59

# %%
def load_datfile(fpath, proto):
    # Returns a dataframe
    df = pd.read_csv(fpath, 
                     index_col=False,
                     names=["ncli",proto])
    return df


def load_collectl(fname):
    df = pd.read_csv(fname,
                     delim_whitespace=True,
                     comment="#",
                     names=collectl_stats)
    return df

def load_data_and_stats(basename):
    pds = []
    for fname in [x for x in os.listdir(".") if 
                  ("server-0" not in x and basename in x)]:
        df_tput = load_datfile(os.path.join(home, fname), basename)
        
        collectl_fname = [x for x in os.listdir(".") if "%s-server-0" % fname in x]
        if len(collectl_fname) > 0:
            df_stats = load_collectl(collectl_fname[0])

        expduration = int(re.search("(?<=_u)\d+", fname).group(0))
            
        newdf = pd.concat([df_tput.sum(), df_stats.mean()])
        newdf["fname"] = fname
        newdf["expduration"] = expduration
        pds.append(newdf)
    return (basename, pd.concat(pds, axis=1).transpose())

def load_data_no_sum(basename):
    pds = []
    for fname in [x for x in os.listdir(".") if 
                  ("server-0" not in x and basename in x)]:
        df_tput = load_datfile(os.path.join(home, fname), basename)
        
        expduration = int(re.search("(?<=_u)\d+", fname).group(0))
        
        collectl_fname = [x for x in os.listdir(".") if "%s-server-0" % fname in x]
        if len(collectl_fname) > 0:
            df_stats = load_collectl(collectl_fname[0])
        
        newdf = pd.concat([df_tput, df_stats])
        newdf["fname"] = fname
        newdf["expduration"] = expduration
        pds.append(newdf)

    return (basename, pd.concat(pds))

# %%
os.listdir(".")
# Out:
# ['32cores_u160_27.dat',
#  '32cores_u160_22.dat-server-0-20171214.tab',
#  '32cores_u160_9.dat-server-0-20171214.tab',
#  '32cores_u160_20.dat',
#  '32cores_u160_3.dat',
#  '32cores_u160_29.dat',
#  '32cores_u160_37.dat-server-0-20171214.tab',
#  '32cores_u160_4.dat',
#  '32cores_u160_21.dat-server-0-20171214.tab',
#  '32cores_u160_15.dat',
#  '32cores_u160_34.dat-server-0-20171214.tab',
#  '32cores_u160_12.dat',
#  '32cores_u160_43.dat-server-0-20171214.tab',
#  '32cores_u160_31.dat-server-0-20171214.tab',
#  '32cores_u160_18.dat-server-0-20171214.tab',
#  '32cores_u160_24.dat-server-0-20171214.tab',
#  '32cores_u160_40.dat-server-0-20171214.tab',
#  '32cores_u160_38.dat',
#  '32cores_u160_44.dat',
#  '32cores_u160_32.dat-server-0-20171214.tab',
#  '32cores_u160_43.dat',
#  '32cores_u160_31.dat',
#  '32cores_u160_36.dat',
#  '32cores_u160_27.dat-server-0-20171214.tab',
#  '32cores_u160_13.dat',
#  '32cores_u160_11.dat-server-0-20171214.tab',
#  '32cores_u160_14.dat',
#  '32cores_u160_38.dat-server-0-20171214.tab',
#  '.ipynb_checkpoints',
#  '32cores_u160_12.dat-server-0-20171214.tab',
#  '32cores_u160_28.dat',
#  '32cores_u160_5.dat',
#  '32cores_u160_2.dat',
#  '32cores_u160_21.dat',
#  '32cores_u160_26.dat',
#  '32cores_u160_37.dat',
#  'throughput.ipynb',
#  '32cores_u160_30.dat',
#  '32cores_u160_42.dat',
#  '32cores_u160_17.dat-server-0-20171214.tab',
#  '32cores_u160_39.dat',
#  '16cores_u160_0.dat',
#  '32cores_u160_14.dat-server-0-20171214.tab',
#  '32cores_u160_28.dat-server-0-20171214.tab',
#  '32cores_u160_23.dat-server-0-20171214.tab',
#  '32cores_u160_8.dat-server-0-20171214.tab',
#  '32cores_u160_33.dat',
#  '32cores_u160_34.dat',
#  '32cores_u160_36.dat-server-0-20171214.tab',
#  '32cores_u160_41.dat',
#  '32cores_u160_44.dat-server-0-20171214.tab',
#  '32cores_u160_20.dat-server-0-20171214.tab',
#  '32cores_u160_35.dat-server-0-20171214.tab',
#  '32cores_u160_17.dat',
#  '32cores_u160_10.dat',
#  '32cores_u160_30.dat-server-0-20171214.tab',
#  '32cores_u160_42.dat-server-0-20171214.tab',
#  '32cores_u160_25.dat-server-0-20171214.tab',
#  '32cores_u160_19.dat-server-0-20171214.tab',
#  '32cores_u160_19.dat',
#  '32cores_u160_33.dat-server-0-20171214.tab',
#  '32cores_u160_1.dat',
#  '32cores_u160_41.dat-server-0-20171214.tab',
#  '32cores_u160_6.dat',
#  '32cores_u160_25.dat',
#  '32cores_u160_8.dat',
#  '32cores_u160_26.dat-server-0-20171214.tab',
#  '32cores_u160_22.dat',
#  '32cores_u160_10.dat-server-0-20171214.tab',
#  '32cores_u160_39.dat-server-0-20171214.tab',
#  'config',
#  '32cores_u160_40.dat',
#  '32cores_u160_13.dat-server-0-20171214.tab',
#  '32cores_u160_35.dat',
#  '32cores_u160_32.dat',
#  '32cores_u160_23.dat',
#  '32cores_u160_24.dat',
#  '32cores',
#  '32cores_u160_9.dat',
#  '32cores_u160_7.dat',
#  '32cores_u160_0.dat',
#  '32cores_u160_16.dat-server-0-20171214.tab',
#  '32cores_u160_18.dat',
#  '32cores_u160_11.dat',
#  '32cores_u160_29.dat-server-0-20171214.tab',
#  '16cores_u160_0.dat-server-0-20171214.tab',
#  '32cores_u160_15.dat-server-0-20171214.tab',
#  '32cores_u160_16.dat']

# %%
df1 = load_data_and_stats("32cores")
df2 = load_data_and_stats("16cores")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-7760606f77c3> in <module>()
# ----> 1 df1 = load_data_and_stats("32cores")
#       2 df2 = load_data_and_stats("16cores")
#
# <ipython-input-5-f951adaa927e> in load_data_and_stats(basename)
#      24             df_stats = load_collectl(collectl_fname[0])
#      25
# ---> 26         expduration = int(re.search("(?<=_u)\d+", fname).group(0))
#      27
#      28         newdf = pd.concat([df_tput.sum(), df_stats.mean()])
#
# AttributeError: 'NoneType' object has no attribute 'group'

# %%
dfs = [df]
groups = [(name, df.drop("fname", axis=1).astype(float).groupby(["expduration"])) for name, df in dfs]
agged = [(name, gp.mean(), gp.std()) for name, gp in groups]
[x.size() for name, x in groups]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-940d1036ec45> in <module>()
# ----> 1 df = load_data_and_stats("tcp_collect")
#       2
#       3 dfs = [df]
#       4 groups = [(name, df.drop("fname", axis=1).astype(float).groupby(["expduration"])) for name, df in dfs]
#       5 agged = [(name, gp.mean(), gp.std()) for name, gp in groups]
#
# <ipython-input-5-f951adaa927e> in load_data_and_stats(basename)
#      30         newdf["expduration"] = expduration
#      31         pds.append(newdf)
# ---> 32     return (basename, pd.concat(pds, axis=1).transpose())
#      33
#      34 def load_data_no_sum(basename):
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, copy)
#     204                        keys=keys, levels=levels, names=names,
#     205                        verify_integrity=verify_integrity,
# --> 206                        copy=copy)
#     207     return op.get_result()
#     208
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy)
#     237
#     238         if len(objs) == 0:
# --> 239             raise ValueError('No objects to concatenate')
#     240
#     241         if keys is None:
#
# ValueError: No objects to concatenate

# %%
traces = []
barwidth_scalar = 1/4

for (name, means, standards) in agged:
    barwidth = means.index.values * barwidth_scalar
    #barwidth = 10
    
    # Collectl data
    traces.append(Bar(
        x = means.index.values,
        y = means["[CPU]Sys%"],
        yaxis = 'y2',
        name = '%s CPU Sys%%' % name,
        width = barwidth,
        opacity=0.6
    ))
    traces.append(Bar(
        x = means.index.values,
        y = means["[CPU]Soft%"],
        yaxis = 'y2',
        name = '%s CPU Soft%%' % name,
        width = barwidth,
        opacity=0.6
    ))
    traces.append(Bar(
        x = means.index.values,
        y = means["[CPU]User%"],
        yaxis = 'y2',
        name = '%s CPU User%%' % name,
        width = barwidth,
        opacity=0.6
    ))
    
    # Throughput
    traces.append(Scatter(
        x = means.index.values,
        y = means[name],
        name = name,
        error_y = dict(
            type='data',
            array=standards[name],
            visible=True
        ),
    ))
    
    
layout = Layout (
    xaxis = {'title': 'experiment duration', 'type': 'log'},
    yaxis = {'title': 'throughput (pps)', 'rangemode': 'tozero'},
    yaxis2 = {'title': 'CPU utilization', 
              'side': 'right', 
              'overlaying': 'y',
              'showgrid': False},
    title = 'Small-packet throughput',
    legend = {'x': 0.01, 'y': 1},
    barmode = "stack"
)

fig = Figure(data=traces, layout=layout)

py.iplot(fig, filename='cpu-throughput')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~theano/20.embed" height="525px" width="100%"></iframe>

# %%
nosum_df = load_data_no_sum("tcp_collect")
nosum_gp = nosum_df[1].groupby("expduration")

# %%
nosum_df_160 = nosum_df[1].loc[nosum_df[1]["expduration"] == 160]

nosum_groups_160 = nosum_df_160.groupby("fname")
nosum_groups_160_described = nosum_groups_160.agg([np.mean, np.std]).sort_values(by=('tcp_collect', 'mean'))

# %%
nosum_groups_160_described.columns.get_level_values(1)
# Out:
# Index(['mean', 'std', 'mean', 'std', 'mean', 'std', 'mean', 'std', 'mean',
#        'std', 'mean', 'std', 'mean', 'std', 'mean', 'std', 'mean', 'std',
#        'mean', 'std', 'mean', 'std', 'mean', 'std', 'mean', 'std', 'mean',
#        'std', 'mean', 'std', 'mean', 'std', 'mean', 'std', 'mean', 'std',
#        'mean', 'std', 'mean', 'std', 'mean', 'std', 'mean', 'std'],
#       dtype='object')

# %%
idx = pd.IndexSlice
nosum_groups_160_described.loc[:, idx[:, "std"]]
# Out:
#                         [CPU]BlkTot   [CPU]Ctx/sec [CPU]Idle% [CPU]Intrpt/sec  \
#                                 std            std        std             std
# fname
# tcp_collect_u160_37.dat    0.000000   84992.822925  10.405609    3.026697e+05
# tcp_collect_u160_1.dat     0.000000  124158.437050  17.143309    4.920501e+05
# tcp_collect_u160_44.dat    0.000000   79738.775332   8.669234    2.469093e+05
# tcp_collect_u160_13.dat    0.000000  126110.012854  14.271756    4.595911e+05
# tcp_collect_u160_22.dat    0.000000  120816.949419  10.787134    3.987407e+05
# tcp_collect_u160_24.dat    0.000000  146815.972620  13.621939    3.877052e+05
# tcp_collect_u160_4.dat     0.000000   76816.795262  13.687844    3.824525e+05
# tcp_collect_u160_28.dat    0.000000   95873.840382   9.876309    2.961784e+05
# tcp_collect_u160_9.dat     0.000000  103757.681319  18.684941    4.958837e+05
# tcp_collect_u160_39.dat    0.000000  157688.279222  30.277329    8.004193e+05
# tcp_collect_u160_18.dat    0.000000  118954.882132  16.624672    4.401585e+05
# tcp_collect_u160_14.dat    0.000000  108533.931396  10.437287    3.476614e+05
# tcp_collect_u160_40.dat    0.000000   96760.701787  17.941199    5.143467e+05
# tcp_collect_u160_3.dat     0.079057  108369.395381  18.456664    5.749268e+05
# tcp_collect_u160_5.dat     0.000000  157982.097531  29.062606    9.535733e+05
# tcp_collect_u160_29.dat    0.000000  135317.279012  23.715969    6.828940e+05
# tcp_collect_u160_8.dat     0.000000  100420.302258  12.937135    3.010846e+05
# tcp_collect_u160_35.dat    0.000000  100407.579333  31.737066    1.042000e+06
# tcp_collect_u160_30.dat    0.000000  155307.571206  22.262245    5.980848e+05
# tcp_collect_u160_19.dat    0.000000  104042.924158  11.317036    2.892427e+05
# tcp_collect_u160_10.dat    0.000000  179758.008101  33.552465    1.032217e+06
# tcp_collect_u160_15.dat    0.000000  135537.054273  25.015780    6.719868e+05
# tcp_collect_u160_31.dat    0.000000  180430.156793  36.538751    1.131072e+06
# tcp_collect_u160_27.dat    0.000000  200673.814222  34.849305    1.072933e+06
# tcp_collect_u160_20.dat    0.000000  166036.976659  27.694423    8.484018e+05
# tcp_collect_u160_7.dat     0.000000  188417.152555  36.360183    1.104072e+06
# tcp_collect_u160_16.dat    0.000000  150680.225693  22.398773    7.999853e+05
# tcp_collect_u160_6.dat     0.000000  176661.824013  36.212161    1.080548e+06
# tcp_collect_u160_43.dat    0.000000  176133.971175  39.286592    1.091385e+06
# tcp_collect_u160_17.dat    0.000000  214040.402663  40.284928    1.295474e+06
# tcp_collect_u160_41.dat    0.000000  216547.133911  34.890394    1.062268e+06
# tcp_collect_u160_36.dat    0.000000  268438.318824  29.633181    9.949452e+05
# tcp_collect_u160_2.dat     0.000000  157597.119499  41.023308    1.397239e+06
# tcp_collect_u160_21.dat    0.000000  275685.950819  39.610269    1.132035e+06
# tcp_collect_u160_42.dat    0.000000  160825.593648  35.257230    1.119346e+06
# tcp_collect_u160_23.dat    0.000000  307417.737687  26.924188    6.654270e+05
# tcp_collect_u160_11.dat    0.000000  113316.409470  31.017594    1.034431e+06
# tcp_collect_u160_38.dat    0.000000  165347.079861  29.712617    1.053679e+06
# tcp_collect_u160_26.dat    0.000000  276533.693025  33.273632    1.096540e+06
# tcp_collect_u160_12.dat    0.000000  195366.208765  22.553218    8.045489e+05
# tcp_collect_u160_0.dat     0.000000  261424.970610  18.972190    6.436783e+05
# tcp_collect_u160_25.dat    0.000000  271102.013574  13.461125    4.141755e+05
# tcp_collect_u160_32.dat    0.000000  214603.486856   9.965025    2.300704e+05
# tcp_collect_u160_34.dat    0.000000  165526.721387   6.910467    1.820243e+05
# tcp_collect_u160_33.dat    0.000000  197171.103974   8.331950    1.822236e+05
#
#                         [CPU]Irq% [CPU]L-Avg1 [CPU]L-Avg15 [CPU]L-Avg5  \
#                               std         std          std         std
# fname
# tcp_collect_u160_37.dat       0.0    8.024629     1.298861    3.451248
# tcp_collect_u160_1.dat        0.0    5.619445     0.740567    2.486781
# tcp_collect_u160_44.dat       0.0    4.130861     0.816202    1.983066
# tcp_collect_u160_13.dat       0.0    5.703241     0.864222    3.185293
# tcp_collect_u160_22.dat       0.0    4.061468     0.640922    1.759491
# tcp_collect_u160_24.dat       0.0   11.377077     0.868339    2.742507
# tcp_collect_u160_4.dat        0.0    3.572700     0.632435    1.465090
# tcp_collect_u160_28.dat       0.0    3.745890     0.804516    2.244801
# tcp_collect_u160_9.dat        0.0    6.343962     0.675237    1.814291
# tcp_collect_u160_39.dat       0.0    5.978897     0.738591    1.796156
# tcp_collect_u160_18.dat       0.0    3.851932     0.375079    0.901579
# tcp_collect_u160_14.dat       0.0    2.872543     0.249642    0.669193
# tcp_collect_u160_40.dat       0.0    2.625139     0.430734    0.568126
# tcp_collect_u160_3.dat        0.0    4.376548     0.347026    0.872410
# tcp_collect_u160_5.dat        0.0    8.986873     0.560672    1.599168
# tcp_collect_u160_29.dat       0.0    5.155132     0.441760    1.170078
# tcp_collect_u160_8.dat        0.0    5.405137     0.273658    0.992386
# tcp_collect_u160_35.dat       0.0   17.617963     1.360774    5.432192
# tcp_collect_u160_30.dat       0.0    5.035144     0.352761    1.094030
# tcp_collect_u160_19.dat       0.0    1.477964     0.183019    0.347088
# tcp_collect_u160_10.dat       0.0    9.234399     0.541646    1.656491
# tcp_collect_u160_15.dat       0.0    6.339357     0.436163    1.394432
# tcp_collect_u160_31.dat       0.0    8.923012     0.647324    1.847041
# tcp_collect_u160_27.dat       0.0    7.968896     0.662769    2.282062
# tcp_collect_u160_20.dat       0.0    7.540587     0.721206    2.198765
# tcp_collect_u160_7.dat        0.0    8.836131     0.602351    1.849492
# tcp_collect_u160_16.dat       0.0    6.199926     0.359771    1.154080
# tcp_collect_u160_6.dat        0.0    8.915710     0.570119    1.750345
# tcp_collect_u160_43.dat       0.0   11.788527     0.677880    2.185614
# tcp_collect_u160_17.dat       0.0   14.437734     0.687383    2.350237
# tcp_collect_u160_41.dat       0.0   11.429857     0.615936    2.384866
# tcp_collect_u160_36.dat       0.0   10.061280     0.464754    1.441357
# tcp_collect_u160_2.dat        0.0   10.579558     0.762044    2.263588
# tcp_collect_u160_21.dat       0.0   12.829290     0.865527    2.759916
# tcp_collect_u160_42.dat       0.0    8.232553     0.724172    2.130281
# tcp_collect_u160_23.dat       0.0    8.735811     0.622199    2.131709
# tcp_collect_u160_11.dat       0.0   13.957176     1.148642    3.640055
# tcp_collect_u160_38.dat       0.0    8.467190     0.948710    3.103462
# tcp_collect_u160_26.dat       0.0    8.840186     0.897180    1.645415
# tcp_collect_u160_12.dat       0.0    3.821597     1.539450    3.359379
# tcp_collect_u160_0.dat        0.0    6.989115     1.413915    3.797340
# tcp_collect_u160_25.dat       0.0   11.162157     1.587665    4.427543
# tcp_collect_u160_32.dat       0.0    6.457235     1.372620    3.715740
# tcp_collect_u160_34.dat       0.0    1.499279     1.087444    1.457455
# tcp_collect_u160_33.dat       0.0    1.419616     1.263610    2.328605
#
#                         [CPU]Nice% [CPU]Proc/sec     ...     [CPU]RunTot  \
#                                std           std     ...             std
# fname                                                ...
# tcp_collect_u160_37.dat        0.0      0.079057     ...        9.132119
# tcp_collect_u160_1.dat         0.0      0.111451     ...       14.571791
# tcp_collect_u160_44.dat        0.0      0.079057     ...        9.758078
# tcp_collect_u160_13.dat        0.0      0.111451     ...       10.223983
# tcp_collect_u160_22.dat        0.0      0.136067     ...        7.405057
# tcp_collect_u160_24.dat        0.0      0.079057     ...       10.915555
# tcp_collect_u160_4.dat         0.0      0.192632     ...       12.516340
# tcp_collect_u160_28.dat        0.0      0.156615     ...        8.071650
# tcp_collect_u160_9.dat         0.0      1.286343     ...       14.321773
# tcp_collect_u160_39.dat        0.0      0.294339     ...       20.886146
# tcp_collect_u160_18.dat        0.0      0.111451     ...       12.516254
# tcp_collect_u160_14.dat        0.0      0.079057     ...       15.899527
# tcp_collect_u160_40.dat        0.0      0.176331     ...       16.346473
# tcp_collect_u160_3.dat         0.0      0.192632     ...       15.037291
# tcp_collect_u160_5.dat         0.0      0.136067     ...       22.069778
# tcp_collect_u160_29.dat        0.0      0.951476     ...       17.996990
# tcp_collect_u160_8.dat         0.0      0.247948     ...       15.154960
# tcp_collect_u160_35.dat        0.0      0.079057     ...       23.455535
# tcp_collect_u160_30.dat        0.0      0.136067     ...       18.820293
# tcp_collect_u160_19.dat        0.0      0.249528     ...       13.172225
# tcp_collect_u160_10.dat        0.0      0.079057     ...       22.844948
# tcp_collect_u160_15.dat        0.0      0.079057     ...       20.778553
# tcp_collect_u160_31.dat        0.0      0.111451     ...       24.715627
# tcp_collect_u160_27.dat        0.0      0.249528     ...       24.315119
# tcp_collect_u160_20.dat        0.0      0.235841     ...       20.789209
# tcp_collect_u160_7.dat         0.0      0.249528     ...       24.543069
# tcp_collect_u160_16.dat        0.0      0.111451     ...       23.962287
# tcp_collect_u160_6.dat         0.0      0.192632     ...       25.292346
# tcp_collect_u160_43.dat        0.0      0.156615     ...       27.112999
# tcp_collect_u160_17.dat        0.0      0.079057     ...       27.913827
# tcp_collect_u160_41.dat        0.0      0.192632     ...       25.127036
# tcp_collect_u160_36.dat        0.0      0.111451     ...       23.982547
# tcp_collect_u160_2.dat         0.0      0.136067     ...       28.591679
# tcp_collect_u160_21.dat        0.0      0.192632     ...       26.981895
# tcp_collect_u160_42.dat        0.0      0.176331     ...       24.744023
# tcp_collect_u160_23.dat        0.0      0.111451     ...       21.198722
# tcp_collect_u160_11.dat        0.0      0.111451     ...       23.298000
# tcp_collect_u160_38.dat        0.0      0.111451     ...       21.792293
# tcp_collect_u160_26.dat        0.0      0.330570     ...       24.914311
# tcp_collect_u160_12.dat        0.0      0.079057     ...       18.239229
# tcp_collect_u160_0.dat         0.0      0.176331     ...       14.047000
# tcp_collect_u160_25.dat        0.0      0.079057     ...       14.166628
# tcp_collect_u160_32.dat        0.0      0.079057     ...        6.186806
# tcp_collect_u160_34.dat        0.0      0.079057     ...        7.361883
# tcp_collect_u160_33.dat        0.0      0.192632     ...        6.363022
#
#                         [CPU]Soft% [CPU]Steal%  [CPU]Sys% [CPU]Totl%  \
#                                std         std        std        std
# fname
# tcp_collect_u160_37.dat   4.488262         0.0   5.779817  10.405609
# tcp_collect_u160_1.dat    7.755288         0.0   9.166247  17.143309
# tcp_collect_u160_44.dat   3.457963         0.0   5.123472   8.669234
# tcp_collect_u160_13.dat   5.488234         0.0   8.478142  14.271756
# tcp_collect_u160_22.dat   4.203356         0.0   6.555397  10.787134
# tcp_collect_u160_24.dat   6.028431         0.0   7.499033  13.621939
# tcp_collect_u160_4.dat    6.189042         0.0   7.321879  13.687844
# tcp_collect_u160_28.dat   3.507405         0.0   6.159946   9.876309
# tcp_collect_u160_9.dat    7.412710         0.0  10.743837  18.684941
# tcp_collect_u160_39.dat  14.435215         0.0  15.601887  30.277329
# tcp_collect_u160_18.dat   7.290790         0.0   9.078614  16.624672
# tcp_collect_u160_14.dat   4.805510         0.0   5.556567  10.437287
# tcp_collect_u160_40.dat   7.985590         0.0   9.697792  17.941199
# tcp_collect_u160_3.dat    8.404392         0.0   9.815834  18.456664
# tcp_collect_u160_5.dat   13.380492         0.0  15.345332  29.062606
# tcp_collect_u160_29.dat  10.502079         0.0  12.850862  23.715969
# tcp_collect_u160_8.dat    5.720945         0.0   7.001210  12.937135
# tcp_collect_u160_35.dat  14.643086         0.0  16.570650  31.737066
# tcp_collect_u160_30.dat  10.123217         0.0  11.869601  22.262245
# tcp_collect_u160_19.dat   5.169821         0.0   5.998834  11.317036
# tcp_collect_u160_10.dat  15.922541         0.0  17.247660  33.552465
# tcp_collect_u160_15.dat  10.682951         0.0  13.840034  25.015780
# tcp_collect_u160_31.dat  17.278263         0.0  18.799169  36.538751
# tcp_collect_u160_27.dat  16.554674         0.0  17.955851  34.849305
# tcp_collect_u160_20.dat  12.069271         0.0  15.238559  27.694423
# tcp_collect_u160_7.dat   17.273229         0.0  18.559219  36.360183
# tcp_collect_u160_16.dat  11.019406         0.0  11.194814  22.398773
# tcp_collect_u160_6.dat   17.082245         0.0  18.610792  36.212161
# tcp_collect_u160_43.dat  18.628019         0.0  20.146004  39.286592
# tcp_collect_u160_17.dat  19.023636         0.0  20.765079  40.284928
# tcp_collect_u160_41.dat  16.815732         0.0  17.680443  34.890394
# tcp_collect_u160_36.dat  15.237552         0.0  14.197617  29.633181
# tcp_collect_u160_2.dat   19.289135         0.0  21.180787  41.023308
# tcp_collect_u160_21.dat  19.453395         0.0  19.703905  39.610269
# tcp_collect_u160_42.dat  15.594093         0.0  19.003790  35.257230
# tcp_collect_u160_23.dat  13.345433         0.0  13.345317  26.924188
# tcp_collect_u160_11.dat  15.099664         0.0  15.490289  31.017594
# tcp_collect_u160_38.dat  13.569939         0.0  15.626979  29.712617
# tcp_collect_u160_26.dat  15.326005         0.0  17.443165  33.273632
# tcp_collect_u160_12.dat  11.061575         0.0  11.407474  22.553218
# tcp_collect_u160_0.dat    9.655309         0.0   9.276566  18.972190
# tcp_collect_u160_25.dat   7.754667         0.0   5.757672  13.461125
# tcp_collect_u160_32.dat   5.034457         0.0   4.951193   9.965025
# tcp_collect_u160_34.dat   3.545299         0.0   3.444751   6.910467
# tcp_collect_u160_33.dat   4.275938         0.0   4.014890   8.331950
#
#                         [CPU]User% [CPU]Wait% ncli  tcp_collect expduration
#                                std        std  std          std         std
# fname
# tcp_collect_u160_37.dat   0.531663        0.0  0.0   202.942157         0.0
# tcp_collect_u160_1.dat    0.566907        0.0  0.0   440.817900         0.0
# tcp_collect_u160_44.dat   0.456909        0.0  0.0   481.414412         0.0
# tcp_collect_u160_13.dat   0.537545        0.0  0.0   929.606858         0.0
# tcp_collect_u160_22.dat   0.512386        0.0  0.0  1471.286654         0.0
# tcp_collect_u160_24.dat   0.563011        0.0  0.0   474.581547         0.0
# tcp_collect_u160_4.dat    0.487219        0.0  0.0   541.316639         0.0
# tcp_collect_u160_28.dat   0.422956        0.0  0.0   801.087677         0.0
# tcp_collect_u160_9.dat    0.784179        0.0  0.0   366.309883         0.0
# tcp_collect_u160_39.dat   0.606049        0.0  0.0  1316.004373         0.0
# tcp_collect_u160_18.dat   0.388312        0.0  0.0  1123.395478         0.0
# tcp_collect_u160_14.dat   0.242821        0.0  0.0   480.976957         0.0
# tcp_collect_u160_40.dat   0.381933        0.0  0.0   817.406771         0.0
# tcp_collect_u160_3.dat    0.313168        0.0  0.0  1175.511297         0.0
# tcp_collect_u160_5.dat    0.752120        0.0  0.0   610.540434         0.0
# tcp_collect_u160_29.dat   0.623946        0.0  0.0   536.173930         0.0
# tcp_collect_u160_8.dat    0.498070        0.0  0.0   579.958015         0.0
# tcp_collect_u160_35.dat   0.818396        0.0  0.0   245.706348         0.0
# tcp_collect_u160_30.dat   0.545853        0.0  0.0   906.033912         0.0
# tcp_collect_u160_19.dat   0.350202        0.0  0.0   745.370281         0.0
# tcp_collect_u160_10.dat   0.763737        0.0  0.0  1863.635890         0.0
# tcp_collect_u160_15.dat   0.676393        0.0  0.0   965.244553         0.0
# tcp_collect_u160_31.dat   0.816111        0.0  0.0   921.310608         0.0
# tcp_collect_u160_27.dat   0.674793        0.0  0.0  1183.219688         0.0
# tcp_collect_u160_20.dat   0.884528        0.0  0.0   785.347020         0.0
# tcp_collect_u160_7.dat    0.779024        0.0  0.0  1116.127975         0.0
# tcp_collect_u160_16.dat   0.444702        0.0  0.0   343.230955         0.0
# tcp_collect_u160_6.dat    0.813385        0.0  0.0  1492.305445         0.0
# tcp_collect_u160_43.dat   0.775408        0.0  0.0  2290.401398         0.0
# tcp_collect_u160_17.dat   0.899948        0.0  0.0  1325.472137         0.0
# tcp_collect_u160_41.dat   0.475790        0.0  0.0  1222.334180         0.0
# tcp_collect_u160_36.dat   0.473180        0.0  0.0   897.708774         0.0
# tcp_collect_u160_2.dat    0.920397        0.0  0.0  1284.292823         0.0
# tcp_collect_u160_21.dat   0.607992        0.0  0.0  1362.861792         0.0
# tcp_collect_u160_42.dat   0.912440        0.0  0.0   928.783481         0.0
# tcp_collect_u160_23.dat   0.496806        0.0  0.0  1921.946809         0.0
# tcp_collect_u160_11.dat   0.533434        0.0  0.0   454.957239         0.0
# tcp_collect_u160_38.dat   0.764560        0.0  0.0   647.043432         0.0
# tcp_collect_u160_26.dat   0.822994        0.0  0.0  1552.876956         0.0
# tcp_collect_u160_12.dat   0.530664        0.0  0.0   517.970059         0.0
# tcp_collect_u160_0.dat    0.472515        0.0  0.0  2189.922949         0.0
# tcp_collect_u160_25.dat   0.290034        0.0  0.0  1281.827170         0.0
# tcp_collect_u160_32.dat   0.328842        0.0  0.0  1493.024540         0.0
# tcp_collect_u160_34.dat   0.331757        0.0  0.0   992.512978         0.0
# tcp_collect_u160_33.dat   0.347441        0.0  0.0  1345.436539         0.0
#
# [45 rows x 22 columns]

# %%
traces = []
barwidth_scalar = 1/4
idx = pd.IndexSlice
#barwidth = 2

# Collectl data
traces.append(Bar(
    y = nosum_groups_160_described.loc[:, idx[:, "mean"]][("[CPU]Totl%", "mean")],
    name = "[CPU]Totl%",
    yaxis = 'y2',
    #width = barwidth,
    opacity=0.6,
    marker = dict(color="rgb(31, 119, 180)"),
))

# Throughput
traces.append(Scatter(
    y = nosum_groups_160_described.loc[:, idx[:, "mean"]][("tcp_collect", "mean")],
    name = "throughput",
    legendgroup = "throughput",        
    error_y = dict(
        type='data',
        array=nosum_groups_160_described.loc[:, idx[:, "std"]][("tcp_collect", "std")],
        visible=True
    ),
    mode="markers",
))
    
    
layout = Layout (
    xaxis = {'title': 'individual experiments'},
    yaxis = {'title': 'throughput (pps)', 'rangemode': 'tozero'},
    yaxis2 = {'title': 'CPU utilization', 
              'side': 'right', 
              'overlaying': 'y',
              'showgrid': False},
    title = 'Cross-core variance in throughput with CPU utilization<br>CPU legend: blue=Sys, orange=User, green=Soft',
    legend = {'x': 0.01, 'y': 1},
    barmode = "stack",
    showlegend = True
)

fig = Figure(data=traces, layout=layout)

py.iplot(fig, filename='crosscore-var-cpu-throughput')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~theano/26.embed" height="525px" width="100%"></iframe>

# %%
data = []

i = 1
for label, df in groups[0][1]:
    data.append(Histogram(x=df["tcp_collect"],
                          nbinsx=40,
                          name="%ss" % label,
                          opacity=0.6,
                          histnorm="probability",
                          xaxis='x%d' % i,
                          yaxis='y%d' % i))
    i += 1
        
nrows = math.ceil(len(data)/2)
fig = plotly.tools.make_subplots(rows=nrows, cols=2,
                                subplot_titles=("20-second experiments", 
                                                "40-second experiments",
                                                "80-second experiments",
                                                "160-second experiments"))

for i, dat in enumerate(data):
    fig.append_trace(dat, math.ceil((i+1)/2), (i % 2) + 1)
    fig['layout']['xaxis%d' % (i + 1)].update(title='throughput (pps)')
    fig['layout']['yaxis%d' % (i + 1)].update(title='frequency')    
    
fig['layout'].update(title='Throughput frequency for varying experiment durations')
fig['layout'].update(showlegend=False)
    
py.iplot(fig, filename="tput_frequency_durations")
# Out:
# This is the format of your plot grid:
# [ (1,1) x1,y1 ]  [ (1,2) x2,y2 ]
# [ (2,1) x3,y3 ]  [ (2,2) x4,y4 ]
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~theano/28.embed" height="525px" width="100%"></iframe>

# %%
data = []

i = 1
for label, df in nosum_gp:
    data.append(Histogram(x=df["tcp_collect"],
                          nbinsx=40,
                          name="%ss" % label,
                          opacity=0.6,
                          histnorm="probability",
                          xaxis='x%d' % i,
                          yaxis='y%d' % i))
    i += 1
        
nrows = math.ceil(len(data)/2)
fig = plotly.tools.make_subplots(rows=nrows, cols=2,
                                subplot_titles=("20-second experiments", 
                                                "40-second experiments",
                                                "80-second experiments",
                                                "160-second experiments"))

for i, dat in enumerate(data):
    fig.append_trace(dat, math.ceil((i+1)/2), (i % 2) + 1)
    fig['layout']['xaxis%d' % (i + 1)].update(title='throughput (pps)')
    fig['layout']['yaxis%d' % (i + 1)].update(title='frequency')    
    
fig['layout'].update(title='Per-process throughput frequency for varying experiment durations')
    
py.iplot(fig, filename="somefile")
# Out:
# This is the format of your plot grid:
# [ (1,1) x1,y1 ]  [ (1,2) x2,y2 ]
# [ (2,1) x3,y3 ]  [ (2,2) x4,y4 ]
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~theano/24.embed" height="525px" width="100%"></iframe>
